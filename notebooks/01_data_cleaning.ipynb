# %% [markdown]
# # Humanitarian Nutrition & Food Security Dashboard
# ## Notebook 1: Data Cleaning and Preprocessing
#
# **Purpose:**
# - Load raw datasets
# - Handle missing values, duplicates, and outliers
# - Merge datasets for analysis
#
# **Instructions:**
# - Update file paths in `data/raw/`
# - Save cleaned data to `data/processed/`

# %%
import pandas as pd
import numpy as np

# Load raw data
# Example: df = pd.read_csv('../data/raw/sample_data.csv')

# Data cleaning steps
# - Handle missing values
# - Handle duplicates
# - Transform variables

# Save processed data
# df.to_csv('../data/processed/cleaned_data.csv', index=False)
